# %% [markdown]
# # 測試

# %%
import sys
sys.path.append('C:/Users/sheng/Desktop/F_Market/Trading/')
#import剛剛的函數包as uf
import utility_f as uf
import datetime
import os
import pandas as pd
import traceback

#獲取今日日期
today = datetime.date.today()
#傳入判斷今天是否為營業日
if_trade = uf.is_open(today)
#如果是N，表示沒開盤，準備寄信
if if_trade=='N':
    #沒開盤應該收件者
    mail_list = ['xx@gmail.com','xxx@gmail.com']
    #標題為三大法人篩選，今日休市
    subject = f'{today} 小幫手三大法人篩選 - 今日休市'
    #郵件內容為空
    body = ''
    #寄信
    uf.send_mail(mail_list, subject, body, 'text' ,None, None)
    exit()
#用control來控制獲得了幾個有開市的資料
control = 0
#迴圈搜索10次
for i in range(0,10):
    #如果control比2還小(0、1、2實際上是三次)，我們就展開搜索
    if control <=2:
        #datetime.timedelta()可以對datetime類型作日期運算
        date_target = today + datetime.timedelta(days =-int(i))
        #用我們的函數is_open判斷是否開盤
        if_trade = uf.is_open(date_target)
        print(date_target)
        print(if_trade)
        #未開盤的話則continue直接進行下一批檢查
        if if_trade=='N':
            continue
        #有開盤則control要記得+1，並且進行三大法人買賣超處理
        else:
            #將日期轉為字串以便傳入twse_data()函數
            convert_today = date_target.strftime('%Y-%m-%d')
            #獲取三大法人買賣超日報
            data = uf.twse_data(convert_today)
            #儲存成excel
            data.to_excel(f'{convert_today}_twse.xlsx')
            #讀取時使用thousands參數讀取，處理數字問題
            data = pd.read_excel(f'{convert_today}_twse.xlsx',thousands=',')
            #刪除檔案避免檔案堆積
            os.remove(f'{convert_today}_twse.xlsx')
            #只保留三大法人買賣超股數大於0的
            d_s = data[(data[u'三大法人買賣超股數']>0)]
            #獲取前50名三大法人買超最大量的
            d_s = d_s[:50] 
            #當control ==0的時候意味著是第一次搜尋到清單，因此當主軸
            if control==0:
                result = set(d_s[u'證券代號'].tolist())
            #如果不是的話我們用intersection函數來取交集
            else:
                result = result.intersection(set(d_s[u'證券代號'].tolist()))
            #全部處理了control才+1，要注意位階，是在if else之外
            control+=1
    else:
        break

# result  = ",".join(result)
print(result)       
# print(type(result))

#創建list備用
target_store = list(result)
print(target_store)
# Out:
# 2023-09-07
# Y
# 2023-09-06
# Y
# 2023-09-05
# Y
# {'00665L', '3231', '2609', '2637', '2610', '0050', '1802', '2890', '2892', '2633', '00753L', '6116', '3576', '2812', '1402', '1303', '6770', '2412', '00882', '2002', '00637L', '2603', '1305', '2887', '2388', '00830', '00903', '5880', '2371', '2618', '2834', '2889', '9919', '2881', '1101', '2303', '2504', '2324', '2606', '3711', '00650L', '2330', '1216', '2888', '2880', '6443', '2356', '2885', '00673R', '00893'}
# ['00665L', '3231', '2609', '2637', '2610', '0050', '1802', '2890', '2892', '2633', '00753L', '6116', '3576', '2812', '1402', '1303', '6770', '2412', '00882', '2002', '00637L', '2603', '1305', '2887', '2388', '00830', '00903', '5880', '2371', '2618', '2834', '2889', '9919', '2881', '1101', '2303', '2504', '2324', '2606', '3711', '00650L', '2330', '1216', '2888', '2880', '6443', '2356', '2885', '00673R', '00893']

# %%
#讀取所有股票清單
all_stock_list = pd.read_excel('C:/Users/sheng/Desktop/F_Market/Trading/stock_list_all.xlsx')
#創建空list備用
stock_name_store = []
#loop符合我們目標的股票
for st in result:
    #dataframe的篩選，篩選出目標股票
    select_data = all_stock_list[(all_stock_list[u'代號']==st)]
    #print(select_data)
    #取得後取股票平稱後轉values再取裡面的元素
    target = select_data['股票名稱'].values[0]
    print(target)
    #append進list
    stock_name_store.append(target)

# %% [markdown]
# # 成品

# %%
import sys
sys.path.append('C:/Users/sheng/Desktop/F_Market/Trading/')
#import剛剛的函數包as uf
import utility_f as uf
import datetime
import os
import pandas as pd
import traceback

#獲取今日日期
today = datetime.date.today()
#傳入判斷今天是否為營業日
if_trade = uf.is_open(today)
#如果是N，表示沒開盤，準備寄信
if if_trade=='N':
    #沒開盤應該收件者
    mail_list = ['xx@gmail.com','xxx@gmail.com']
    #標題為三大法人篩選，今日休市
    subject = f'{today} 小幫手三大法人篩選 - 今日休市'
    #郵件內容為空
    body = ''
    #寄信
    uf.send_mail(mail_list, subject, body, 'text' ,None, None)
    exit()
#用control來控制獲得了幾個有開市的資料
control = 0
#迴圈搜索10次
for i in range(0,10):
    #如果control比2還小(0、1、2實際上是三次)，我們就展開搜索
    if control <=2:
        #datetime.timedelta()可以對datetime類型作日期運算
        date_target = today + datetime.timedelta(days =-int(i))
        #用我們的函數is_open判斷是否開盤
        if_trade = uf.is_open(date_target)
        print(date_target)
        print(if_trade)
        #未開盤的話則continue直接進行下一批檢查
        if if_trade=='N':
            continue
        #有開盤則control要記得+1，並且進行三大法人買賣超處理
        else:
            #將日期轉為字串以便傳入twse_data()函數
            convert_today = date_target.strftime('%Y%m%d')
            #獲取三大法人買賣超日報
            data = uf.twse_data(convert_today)
            #儲存成excel
            data.to_excel(f'{convert_today}_twse.xlsx')
            #讀取時使用thousands參數讀取，處理數字問題
            data = pd.read_excel(f'{convert_today}_twse.xlsx',thousands=',')
            #刪除檔案避免檔案堆積
            os.remove(f'{convert_today}_twse.xlsx')
            #只保留三大法人買賣超股數大於0的
            d_s = data[(data[u'三大法人買賣超股數']>0)]
            #獲取前50名三大法人買超最大量的
            d_s = d_s[:50] 
            #當control ==0的時候意味著是第一次搜尋到清單，因此當主軸
            if control==0:
                result = set(d_s[u'證券代號'].tolist())
            #如果不是的話我們用intersection函數來取交集
            else:
                result = result.intersection(set(d_s[u'證券代號'].tolist()))
            #全部處理了control才+1，要注意位階，是在if else之外
            control+=1
    else:
        break

#創建list備用
target_store = list(result)

#讀取所有股票清單，本國上市證券國際證券辨識號碼一覽表
all_stock_list = pd.read_excel('C:/Users/sheng/Desktop/F_Market/Trading/stock_list_all.xlsx')
#創建空list備用
stock_name_store = []
#loop符合我們目標的股票
for st in target_store:
    #dataframe的篩選，篩選出目標股票
    select_data = all_stock_list[(all_stock_list[u'代號']==st)]
    #取得後取股票平稱後轉values再取裡面的元素
    target = select_data['股票名稱'].values[0]
    #append進list
    stock_name_store.append(target)    
    
#創建空的dataframe準備寄信
empty_df = pd.DataFrame()
empty_df['日期'] = len(target_store)*[today]
empty_df['股票代號'] = target_store
empty_df['股票名稱'] = stock_name_store

#將dataframe轉為html格式
empty_df = empty_df.to_html(index=False)
print(empty_df)
#製作html格式
body = f'''<html>
            <font face="微軟正黑體"></font>
            <body>
            <h4>
            小幫手系列偵測下表連續三日法人買超 
            </h4>
            {empty_df}
            <h5>投資理財有賺有賠，請謹慎評估風險</h5>
            </body>
            </html>'''
#寄信名單
mail_list = ['xx@gmail.com','xxx@gmail.com']
#標題我們加上日期，淺顯易懂
subject = f'{today}  小幫手三大法人篩選'
#寄信
uf.send_mail(mail_list, subject, body,'html', None, None)

print('Its OK')

# %% [markdown]
# # 最終

# %%
import sys
sys.path.append('C:/Users/sheng/Desktop/F_Market/Trading')
#import剛剛的函數包as uf
import utility_f as uf
import datetime
import os
import pandas as pd
import traceback
try:
    #獲取今日日期
    today = datetime.date.today()
    #傳入判斷今天是否為營業日
    if_trade = uf.is_open(today)
    #如果是N，表示沒開盤，準備寄信
    if if_trade=='N':
        #沒開盤應該收件者
        mail_list = ['xx@gmail.com','xxx@gmail.com']
        #標題為三大法人篩選，今日休市
        subject = f'{today} 小幫手三大法人篩選 - 今日休市'
        #郵件內容為空
        body = ''
        #寄信
        uf.send_mail(mail_list, subject, body, 'text' ,None, None)
        exit()
    #用control來控制獲得了幾個有開市的資料
    control = 0
    #迴圈搜索10次
    for i in range(0,10):
        #如果control比2還小(0、1、2實際上是三次)，我們就展開搜索
        if control <=2:
            #datetime.timedelta()可以對datetime類型作日期運算
            date_target = today + datetime.timedelta(days =-int(i))
            #用我們的函數is_open判斷是否開盤
            if_trade = uf.is_open(date_target)
            print(date_target)
            print(if_trade)
            #未開盤的話則continue直接進行下一批檢查
            if if_trade=='N':
                continue
            #有開盤則control要記得+1，並且進行三大法人買賣超處理
            else:
                #將日期轉為字串以便傳入twse_data()函數
                convert_today = date_target.strftime('%Y-%m-%d')
                #獲取三大法人買賣超日報
                data = uf.twse_data(convert_today)
                #儲存成excel
                data.to_excel(f'{convert_today}_twse.xlsx')
                #讀取時使用thousands參數讀取，處理數字問題
                data = pd.read_excel(f'{convert_today}_twse.xlsx',thousands=',')
                #刪除檔案避免檔案堆積
                os.remove(f'{convert_today}_twse.xlsx')
                #只保留三大法人買賣超股數大於0的
                d_s = data[(data[u'三大法人買賣超股數']>0)]
                #獲取前50名三大法人買超最大量的
                d_s = d_s[:50] 
                #當control ==0的時候意味著是第一次搜尋到清單，因此當主軸
                if control==0:
                    result = set(d_s[u'證券代號'].tolist())
                #如果不是的話我們用intersection函數來取交集
                else:
                    result = result.intersection(set(d_s[u'證券代號'].tolist()))
                #全部處理了control才+1，要注意位階，是在if else之外
                control+=1
        else:
            break
    
    #創建list備用
    target_store = list(result)
    
    #讀取所有股票清單，本國上市證券國際證券辨識號碼一覽表
    all_stock_list = pd.read_excel('C:/Users/sheng/Desktop/F_Market/Trading/stock_list_all.xlsx')
    #創建空list備用
    stock_name_store = []
    #loop符合我們目標的股票
    for st in target_store:
        #dataframe的篩選，篩選出目標股票
        select_data = all_stock_list[(all_stock_list[u'代號']==st)]
        #取得後取股票平稱後轉values再取裡面的元素
        target = select_data['股票名稱'].values[0]
        #append進list
        stock_name_store.append(target)    
        
    #創建空的dataframe準備寄信
    empty_df = pd.DataFrame()
    empty_df['日期'] = len(target_store)*[today]
    empty_df['股票代號'] = target_store
    empty_df['股票名稱'] = stock_name_store
    
    #將dataframe轉為html格式
    empty_df = empty_df.to_html(index=False)
    print(empty_df)
    #製作html格式
    body = f'''<html>
                <font face="微軟正黑體"></font>
                <body>
                <h4>
                小幫手系列偵測下表連續三日法人買超 
                </h4>
                {empty_df}
                <h5>投資理財有賺有賠，請謹慎評估風險</h5>
                </body>
                </html>'''
    #寄信名單
    mail_list = ['xx@gmail.com','xxx@gmail.com']
    #標題我們加上日期，淺顯易懂
    subject = f'{today}  小幫手三大法人篩選'
    #寄信
    uf.send_mail(mail_list, subject, body,'html', None, None)
except SystemExit:
    print('Its OK')
except:
    #收件名單
#     mail_list = ['a********@gmail.com','0********@gm.scu.edu.tw']
    mail_list = ['xx@gmail.com','xxx@gmail.com']
    #標題我們加上日期，淺顯易懂
    subject = f'{today}  小幫手三大法人篩選異常'
    #內容就是剛剛篩選完成的股票
    body = traceback.format_exc()
    #寄信
    uf.send_mail(mail_list, subject, body, 'text' ,None, None)
# Out:
# 2023-09-07
# Y
# 2023-09-06
# Y
# 2023-09-05
# Y
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>日期</th>
#       <th>股票代號</th>
#       <th>股票名稱</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2023-09-07</td>
#       <td>00665L</td>
#       <td>富邦恒生國企正2</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>3231</td>
#       <td>緯創</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2609</td>
#       <td>陽明</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2637</td>
#       <td>慧洋-KY</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2610</td>
#       <td>華航</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>0050</td>
#       <td>元大台灣50</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>1802</td>
#       <td>台玻</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2890</td>
#       <td>永豐金</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2892</td>
#       <td>第一金</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2633</td>
#       <td>台灣高鐵</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>00753L</td>
#       <td>中信中國50正2</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>6116</td>
#       <td>彩晶</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>3576</td>
#       <td>聯合再生</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2812</td>
#       <td>台中銀</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>1402</td>
#       <td>遠東新</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>1303</td>
#       <td>南亞</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>6770</td>
#       <td>力積電</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2412</td>
#       <td>中華電</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>00882</td>
#       <td>中信中國高股息</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2002</td>
#       <td>中鋼</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>00637L</td>
#       <td>元大滬深300正2</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2603</td>
#       <td>長榮</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>1305</td>
#       <td>華夏</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2887</td>
#       <td>台新金</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2388</td>
#       <td>威盛</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>00830</td>
#       <td>國泰費城半導體</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>00903</td>
#       <td>富邦元宇宙</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>5880</td>
#       <td>合庫金</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2371</td>
#       <td>大同</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2618</td>
#       <td>長榮航</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2834</td>
#       <td>臺企銀</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2889</td>
#       <td>國票金</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>9919</td>
#       <td>康那香</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2881</td>
#       <td>富邦金</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>1101</td>
#       <td>台泥</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2303</td>
#       <td>聯電</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2504</td>
#       <td>國產</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2324</td>
#       <td>仁寶</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2606</td>
#       <td>裕民</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>3711</td>
#       <td>日月光投控</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>00650L</td>
#       <td>復華香港正2</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2330</td>
#       <td>台積電</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>1216</td>
#       <td>統一</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2888</td>
#       <td>新光金</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2880</td>
#       <td>華南金</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>6443</td>
#       <td>元晶</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2356</td>
#       <td>英業達</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>2885</td>
#       <td>元大金</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>00673R</td>
#       <td>期元大S&amp;P原油反1</td>
#     </tr>
#     <tr>
#       <td>2023-09-07</td>
#       <td>00893</td>
#       <td>國泰智能電動車</td>
#     </tr>
#   </tbody>
# </table>
